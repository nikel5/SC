# %%
#to display SVG images
from IPython.display import SVG

# %%
import pandas as pd

# %%
import pygal as pg

# %%
# read data
health_data = pd.read_csv('Dem_Health_Full.txt', sep = '\t')

# %%
health_data.head(2)
health_data.tail ()
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 3136  Sweetwater    WY                   4      8.6              10.2
# 3137       Teton    WY                   5      5.6               3.5
# 3138       Uinta    WY                  10     10.6               7.0
# 3139    Washakie    WY                   4     11.1               9.1
# 3140      Weston    WY                   3      9.9              11.7
#
#       Suicide  Total_Births  Total_Deaths
# 3136     27.9        2756.0        1264.0
# 3137     13.1        1931.0         680.0
# 3138     18.4        3186.0        1060.0
# 3139     14.1         974.0         844.0
# 3140     15.8         670.0         629.0

# %%
help(health_data)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to np.arange(n) if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
#  |      Column labels to use for resulting frame. Will default to
#  |      np.arange(n) if no column labels are provided
#  |  dtype : dtype, default None
# ...

# %%
dir (health_data)
# Out:
# ['County',
#  'Infant_Mortality',
#  'Population_Density',
#  'Poverty',
#  'State',
#  'Suicide',
#  'T',
#  'Total_Births',
#  'Total_Deaths',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
health_data['State']
# Out:
# 0       AL
# 1       AL
# 2       AL
# 3       AL
# 4       AL
# 5       AL
# 6       AL
# 7       AL
# 8       AL
# 9       AL
# 10      AL
# 11      AL
# 12      AL
# 13      AL
# 14      AL
# 15      AL
# 16      AL
# 17      AL
# 18      AL
# 19      AL
# 20      AL
# 21      AL
# 22      AL
# 23      AL
# 24      AL
# 25      AL
# 26      AL
# 27      AL
# 28      AL
# 29      AL
#         ..
# 3111    WI
# 3112    WI
# 3113    WI
# 3114    WI
# 3115    WI
# 3116    WI
# 3117    WI
# 3118    WY
# 3119    WY
# 3120    WY
# 3121    WY
# 3122    WY
# 3123    WY
# 3124    WY
# 3125    WY
# 3126    WY
# 3127    WY
# 3128    WY
# 3129    WY
# 3130    WY
# 3131    WY
# 3132    WY
# 3133    WY
# 3134    WY
# 3135    WY
# 3136    WY
# 3137    WY
# 3138    WY
# 3139    WY
# 3140    WY
# Name: State, dtype: object

# %%
health_data[['State', 'Poverty']]
# Out:
#      State  Poverty
# 0       AL     10.4
# 1       AL     10.2
# 2       AL     22.1
# 3       AL     16.8
# 4       AL     11.9
# 5       AL     26.2
# 6       AL     20.0
# 7       AL     16.4
# 8       AL     16.2
# 9       AL     15.2
# 10      AL     14.9
# 11      AL     18.7
# 12      AL     19.2
# 13      AL     14.0
# 14      AL     14.0
# 15      AL     13.7
# 16      AL     14.0
# 17      AL     22.0
# 18      AL     13.4
# 19      AL     17.5
# 20      AL     17.6
# 21      AL     13.3
# 22      AL     15.8
# 23      AL     25.0
# 24      AL     15.1
# 25      AL     12.5
# 26      AL     18.6
# 27      AL     15.7
# 28      AL     16.1
# 29      AL     17.4
# ...    ...      ...
# 3111    WI      9.7
# 3112    WI      4.6
# 3113    WI      4.1
# 3114    WI      7.4
# 3115    WI      9.6
# 3116    WI      7.5
# 3117    WI      7.8
# 3118    WY     14.4
# 3119    WY     13.2
# 3120    WY      7.9
# 3121    WY     12.2
# 3122    WY     10.5
# 3123    WY      8.5
# ...

# %%
health_data.loc[0,:]
#get all columns in one row
# Out:
# County                Autauga
# State                      AL
# Population_Density         82
# Poverty                  10.4
# Infant_Mortality          5.9
# Suicide                  16.6
# Total_Births             3048
# Total_Deaths             1867
# Name: 0, dtype: object

# %%
health_data.loc[0,['Population_Density', 'Poverty']]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
health_data.iloc [0,2:4]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
health_data [(health_data ['State'] == 'AL') | (health_data ['State']== 'TX')]
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 0        Autauga    AL                  82     10.4               5.9
# 1        Baldwin    AL                 102     10.2               7.1
# 2        Barbour    AL                  32     22.1               7.1
# 3           Bibb    AL                  35     16.8               9.8
# 4         Blount    AL                  86     11.9               9.0
# 5        Bullock    AL                  18     26.2              13.3
# 6         Butler    AL                  27     20.0               5.8
# 7        Calhoun    AL                 184     16.4               9.5
# 8       Chambers    AL                  59     16.2               7.5
# 9       Cherokee    AL                  44     15.2               7.4
# 10       Chilton    AL                  60     14.9              10.5
# 11       Choctaw    AL                  16     18.7              10.8
# ...

# %%
#cleaning data
health_data.iloc [3126]
# Out:
# County                Hot Springs
# State                          WY
# Population_Density              2
# Poverty                      11.6
# Infant_Mortality              NaN
# Suicide                      23.9
# Total_Births                  437
# Total_Deaths                  627
# Name: 3126, dtype: object

# %%
health_data.fillna(0, inplace = True)
health_data.iloc[3126]
# Out:
# County                Hot Springs
# State                          WY
# Population_Density              2
# Poverty                      11.6
# Infant_Mortality                0
# Suicide                      23.9
# Total_Births                  437
# Total_Deaths                  627
# Name: 3126, dtype: object

# %%
#cleaning sicide values
health_data.head(6)
health_data['Suicide'].replace (-1111.1,0,inplace=True)

# %%
health_data.head(6)
# Out:
#     County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0  Autauga    AL                  82     10.4               5.9     16.6
# 1  Baldwin    AL                 102     10.2               7.1     14.3
# 2  Barbour    AL                  32     22.1               7.1     10.3
# 3     Bibb    AL                  35     16.8               9.8     14.8
# 4   Blount    AL                  86     11.9               9.0     14.4
# 5  Bullock    AL                  18     26.2              13.3      0.0
#
#    Total_Births  Total_Deaths
# 0        3048.0        1867.0
# 1        5471.0        4388.0
# 2        1835.0        1538.0
# 3        2801.0        2012.0
# 4        3318.0        2453.0
# 5        1604.0        1381.0

# %%
a_tuple = (1,2)

# %%
a_tuple
# Out:
# (1, 2)

# %%
a_list = [1,2]

# %%
type (a_list)
# Out:
# list

# %%
nested_list = [(1,2), (3,4)]
nested_list
# Out:
# [(1, 2), (3, 4)]

# %%
#correlation of population density and poverty in state of Alabama via scatter plot
data_for_a1 = health_data.loc[health_data['State'] == 'AL', ['Population_Density', 'Poverty']]
data_for_a1.head()
# Out:
#    Population_Density  Poverty
# 0                  82     10.4
# 1                 102     10.2
# 2                  32     22.1
# 3                  35     16.8
# 4                  86     11.9

# %%
lst = [tuple (x) for x in data_for_a1.values] 
lst
# Out:
# [(82.0, 10.4),
#  (102.0, 10.199999999999999),
#  (32.0, 22.100000000000001),
#  (35.0, 16.800000000000001),
#  (86.0, 11.9),
#  (18.0, 26.199999999999999),
#  (27.0, 20.0),
#  (184.0, 16.399999999999999),
#  (59.0, 16.199999999999999),
#  (44.0, 15.199999999999999),
#  (60.0, 14.9),
#  (16.0, 18.699999999999999),
#  (22.0, 19.199999999999999),
#  (23.0, 14.0),
#  (26.0, 14.0),
#  (67.0, 13.699999999999999),
#  (92.0, 14.0),
#  (16.0, 22.0),
#  (17.0, 13.4),
#  (36.0, 17.5),
#  (23.0, 17.600000000000001),
#  (108.0, 13.300000000000001),
#  (87.0, 15.800000000000001),
#  (45.0, 25.0),
#  (86.0, 15.1),
#  (119.0, 12.5),
#  (40.0, 18.600000000000001),
#  (193.0, 15.699999999999999),
#  (29.0, 16.100000000000001),
#  (48.0, 17.399999999999999),
#  (45.0, 17.600000000000001),
#  (15.0, 24.899999999999999),
#  (28.0, 20.600000000000001),
#  (30.0, 16.300000000000001),
#  (162.0, 15.300000000000001),
#  (50.0, 14.5),
#  (591.0, 14.4),
#  (25.0, 16.100000000000001),
#  (131.0, 15.6),
# ...

# %%
#creating scatter plot
scatter_plot = pg.XY(stroke=False)
scatter_plot.add('AL', lst)
SVG(scatter_plot.render ())

# %%
# Adding Title to the Graph
scatter_plot = pg.XY(stroke=True)
scatter_plot.title = 'Population Density vs Poverty Correlation'
scatter_plot.add('AL', lst)
SVG (scatter_plot.render())

# %%
#adding label to x-axis and y-axis
scatter_plot = pg.XY(stroke=True, x_title = 'Population Density', \
                     y_title = 'Poverty')
                        
scatter_plot = pg.XY(stroke=True)
scatter_plot.title = 'Population Density vs Poverty Correlation'
scatter_plot.add('AL', lst)
SVG (scatter_plot.render())

# %%
data_for_a1 = health_data.loc[health_data['State'] == 'PA', ['Population_Density', 'Poverty']]
data_for_a1.head()
# Out:
#       Population_Density  Poverty
# 2242                 192      7.5
# 2243                1693     10.8
# 2244                 108     11.1
# 2245                 409     10.5
# 2246                  49     10.7

# %%
lstpa = [tuple (x) for x in data_for_a1.values] 
lstpa
# Out:
# [(192.0, 7.5),
#  (1693.0, 10.800000000000001),
#  (108.0, 11.1),
#  (409.0, 10.5),
#  (49.0, 10.699999999999999),
#  (461.0, 10.1),
#  (241.0, 12.300000000000001),
#  (54.0, 11.199999999999999),
#  (1023.0, 5.5999999999999996),
#  (231.0, 8.1999999999999993),
#  (215.0, 11.800000000000001),
#  (14.0, 10.1),
#  (163.0, 9.0999999999999996),
#  (127.0, 11.5),
#  (627.0, 5.2999999999999998),
#  (67.0, 12.699999999999999),
#  (72.0, 12.800000000000001),
#  (42.0, 12.4),
#  (134.0, 11.1),
#  (88.0, 12.300000000000001),
#  (405.0, 6.2000000000000002),
#  (484.0, 8.9000000000000004),
#  (3016.0, 8.9000000000000004),
#  (41.0, 8.1999999999999993),
#  (350.0, 12.6),
#  (185.0, 15.9),
#  (13.0, 12.9),
#  (178.0, 8.1999999999999993),
#  (34.0, 9.4000000000000004),
#  (69.0, 14.6),
#  (53.0, 11.9),
#  (107.0, 14.199999999999999),
#  (70.0, 11.699999999999999),
#  (60.0, 8.5),
#  (457.0, 10.199999999999999),
#  (517.0, 8.3000000000000007),
#  (257.0, 12.199999999999999),
# ...

# %%
#adding the values for the state of texas to the same graph
scatter_plot = pg.XY(stroke=False, x_title = 'Population Density', \
                     y_title = 'Poverty')
                        
scatter_plot = pg.XY(stroke=False)
scatter_plot.title = 'Population Density vs Poverty Correlation'
scatter_plot.add('AL', lst)
scatter_plot.add('PA',lstpa)
SVG (scatter_plot.render())

# %%
#how for loops work
for i in range(0,6):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (0,6,2):
    print (i)
# Out:
# 0
# 2
# 4

# %%
# changing the x-axis
scatter_plot = pg.XY(stroke=False, x_title = 'Population Density', \
                     y_title = 'Poverty')                        
scatter_plot.title = 'Population Density vs Poverty Correlation'
scatter_plot.x_labels = (i for i in range(0,2000,100))
scatter_plot.add('AL', lst)
scatter_plot.add('PA',lstpa)
SVG (scatter_plot.render())

# %%
#adjusting the x axis range
scatter_plot = pg.XY(stroke=False, x_title = 'Population Density', \
                     y_title = 'Poverty', xrange=(0,100))                        
scatter_plot.title = 'Population Density vs Poverty Correlation'
#scatter_plot.x_labels = (i for i in range(0,2000,100))
scatter_plot.add('AL', lst)
scatter_plot.add('PA',lstpa)
SVG (scatter_plot.render())

# %%
#adjusting the dot size
scatter_plot = pg.XY(stroke=False, x_title = 'Population Density', \
                     y_title = 'Poverty', xrange=(0,100), dots_size = 1)                        
scatter_plot.title = 'Population Density vs Poverty Correlation'
#scatter_plot.x_labels = (i for i in range(0,2000,100))
scatter_plot.add('AL', lst)
scatter_plot.add('PA',lstpa)
SVG (scatter_plot.render())

# %%
al = health_data.loc[health_data['State'] == 'AL', ['Poverty']] #requesting all rows for Alabama, narrowed down to Poverty column
poverty_mean_al = al['Poverty'].mean()
poverty_mean_al
# Out:
# 17.085074626865676

# %%
# mean of poverty in a state

def mean_of_column (state_name, column_name):
    state_df = health_data.loc[health_data ['State'] == state_name, [column_name]]
    return state_df[column_name].mean()
mean_of_column('TX', 'Poverty')
# Out:
# 16.793307086614174

# %%
def mean_of_column (state_name, column_name):
    state_df = health_data.loc[health_data ['State'] == state_name, [column_name]]
    return state_df[column_name].mean()
mean_of_column('AL', 'Poverty')
# Out:
# 17.085074626865676

# %%
health_data['State'].unique()
type(health_data['State'].unique())
# Out:
# numpy.ndarray

# %%
health_data['State'].unique()
type(health_data['State'].unique())
list(health_data['State'].unique())
# Out:
# ['AL',
#  'AK',
#  'AZ',
#  'AR',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'DC',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NE',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']

# %%
# vertical Bars
bar_chart = pg.Bar()
bar_chart.title = 'Mean of Poverty across all states'
for state in list(health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state,'Poverty'))
SVG(bar_chart.render())

# %%
# horizontal Bars
bar_chart = pg.HorizontalBar()
bar_chart.title = 'Mean of Poverty across all states'
for state in list(health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state,'Poverty'))
SVG(bar_chart.render())

# %%
#scaling legends to data
bar_chart = pg.HorizontalBar(legend_at_bottom=True,\
                             legend_at_bottom_columns = 11)
bar_chart.title = 'Mean of Poverty across all states'
for state in list(health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state,'Poverty'))
SVG(bar_chart.render())
